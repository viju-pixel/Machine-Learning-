# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset=pd.read_csv("D:\\datasets\\1000_Companies.csv")
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
x=dataset.iloc[:, :-1] # this is input variable means independent variable 
# or x=dataset.drop('profit',axis='columns')

x
# Out:
#      R&D Spend  Administration  Marketing Spend       State
# 0    165349.20     136897.8000     471784.10000    New York
# 1    162597.70     151377.5900     443898.53000  California
# 2    153441.51     101145.5500     407934.54000     Florida
# 3    144372.41     118671.8500     383199.62000    New York
# 4    142107.34      91391.7700     366168.42000     Florida
# 5    131876.90      99814.7100     362861.36000    New York
# 6    134615.46     147198.8700     127716.82000  California
# 7    130298.13     145530.0600     323876.68000     Florida
# 8    120542.52     148718.9500     311613.29000    New York
# 9    123334.88     108679.1700     304981.62000  California
# 10   101913.08     110594.1100     229160.95000     Florida
# 11   100671.96      91790.6100     249744.55000  California
# 12    93863.75     127320.3800     249839.44000     Florida
# 13    91992.39     135495.0700     252664.93000  California
# 14   119943.24     156547.4200     256512.92000     Florida
# ...

# %%
y=dataset.iloc[:, 4] # target or output variable
y
# Out:
# 0      192261.83000
# 1      191792.06000
# 2      191050.39000
# 3      182901.99000
# 4      166187.94000
# 5      156991.12000
# 6      156122.51000
# 7      155752.60000
# 8      152211.77000
# 9      149759.96000
# 10     146121.95000
# 11     144259.40000
# 12     141585.52000
# 13     134307.35000
# 14     132602.65000
# 15     129917.04000
# 16     126992.93000
# 17     125370.37000
# 18     124266.90000
# 19     122776.86000
# 20     118474.03000
# 21     111313.02000
# 22     110352.25000
# 23     108733.99000
# 24     108552.04000
# 25     107404.34000
# 26     105733.54000
# 27     105008.31000
# 28     103282.38000
# 29     101004.64000
#            ...
# 970     60869.96038
# 971    110395.79400
# 972    161076.62960
# 973    107704.77620
# 974    141344.20750
# 975    168760.98050
# 976     97599.36358
# 977     89558.77320
# 978     99322.46927
# 979     60065.21791
# 980    102489.32740
# 981     94400.89669
# 982    154569.49220
# 983     90808.60147
# ...

# %%
# convert column into categorial columns 
#states=pd.get_dummies(x['State'],drop_first=True)
x=pd.drop('State',axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-637f409d8bc9> in <module>
#       1 # convert column into categorial columns
#       2 #states=pd.get_dummies(x['State'],drop_first=True)
# ----> 3 x=pd.drop('State',axis=1)
#       4
#
# AttributeError: module 'pandas' has no attribute 'drop'
