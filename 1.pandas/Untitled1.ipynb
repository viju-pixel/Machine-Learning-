# %%
import pandas as pd

# %%
bond=pd.read_csv("D:\datasets\jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(10)
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Casino Royale           145.3                3.3
# ...

# %%
bond.sample(n=3,axis="columns")
#bond.sample(n=3,axis=1)
# Out:
#                                  Budget           Actor  Bond_Actor_Salary
# Film
# A View to a Kill                   54.5     Roger Moore                9.1
# Casino Royale                     145.3    Daniel Craig                3.3
# Casino Royale                      85.0     David Niven                NaN
# Diamonds Are Forever               34.7    Sean Connery                5.8
# Die Another Day                   154.2  Pierce Brosnan               17.9
# Dr. No                              7.0    Sean Connery                0.6
# For Your Eyes Only                 60.2     Roger Moore                NaN
# From Russia with Love              12.6    Sean Connery                1.6
# GoldenEye                          76.9  Pierce Brosnan                5.1
# Goldfinger                         18.6    Sean Connery                3.2
# Licence to Kill                    56.7  Timothy Dalton                7.9
# ...

# %%
bond.sort_values("Box Office",ascending=False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(n=3,columns="Box Office") # or we can use it
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.nlargest(n=3,columns="Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond=pd.read_csv("D:\datasets\jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
mask=bond['Actor']=="Sean Connery"
bond[mask].head(7)
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.where(mask).head(7)
# Out:
#                         Year         Actor       Director  Box Office  Budget  \
# Film
# A View to a Kill         NaN           NaN            NaN         NaN     NaN
# Casino Royale            NaN           NaN            NaN         NaN     NaN
# Casino Royale            NaN           NaN            NaN         NaN     NaN
# Diamonds Are Forever  1971.0  Sean Connery   Guy Hamilton       442.5    34.7
# Die Another Day          NaN           NaN            NaN         NaN     NaN
# Dr. No                1962.0  Sean Connery  Terence Young       448.8     7.0
# For Your Eyes Only       NaN           NaN            NaN         NaN     NaN
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    NaN
# Casino Royale                       NaN
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                     NaN
# Dr. No                              0.6
# For Your Eyes Only                  NaN

# %%
vijay=bond['Box Office'] >800
bond.where(vijay)
bond[vijay]
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond Actor Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Thunderball                4.7

# %%
mask2=bond["Box Office"]>800
bond.where(mask & mask2)      # its checks both coindition and gives only sean connerry and its box offce is more than 800
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
bond=pd.read_csv("D:\datasets\jamesbond.csv",index_col="Film")
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.columns=[x.replace(" ","_") for x in bond.columns]
bond.head(1)                              # its replace  space in columns names to underscore
# Out:
#                   Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1

# %%
bond.query('Actor=="Sean Connery" ')
bond.query("Director=='John Glen' ")
bond.query("actor !=='Rooger Moore'")
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\vijay\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3325, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-14-ac4b3f17ee76>", line 3, in <module>
#     bond.query("actor !=='Rooger Moore'")
#
#   File "C:\Users\vijay\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3088, in query
#     res = self.eval(expr, **kwargs)
#
#   File "C:\Users\vijay\Anaconda3\lib\site-packages\pandas\core\frame.py", line 3203, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "C:\Users\vijay\Anaconda3\lib\site-packages\pandas\core\computation\eval.py", line 294, in eval
#     truediv=truediv)
#
#   File "C:\Users\vijay\Anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 749, in __init__
#     self.terms = self.parse()
#
#   File "C:\Users\vijay\Anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 766, in parse
# ...

# %%
bond.query("Box_Office>800")

# %%
bond.query("Actor=='Roger Moore'" or "Director=='John Glen'") or
#ond.query("Actor=='Roger Moore'" or "Director=='John Glen'")

# %%
def convert_to_string_and_add_Millions(number):
    return str(number)+"millions!"
bond['Budget'].apply(convert_to_string_and_add_Millions)

# %%
a=["Box Office",'Budget','Bond Actor Salary']

# %%
def good_movies(a):
    actor=a[1]
    bugdet=a[4]
    if actor =="Pierce Brosnan":
        return "the best"
    elif actor=="Rooger Moore" and budget>40:
        return "enjoyable"
    else:
        return " i have no clue "
superman=bond.apply(good_movies,axis="columns")
superman

# %%
superman.value_counts()

# %% [markdown]
# # copy

# %%
director=bond["Director"].copy()
director.head(3)

# %%
director["A View to  a kill"]="Mister john glen"  # original data not effcect by the copy methode
director.head()

# %%
n=int(input("enter the no."))
if(n%2==0):
    if(n>=2 and n<=5):
        print("not weird")
    elif(n>=6 and n<=20):
        print("weird")
    elif(n>20):
        print("not weird")
        
else:
    print("weird")
