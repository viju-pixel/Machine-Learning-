# %% [markdown]
# ### Que 1

# %% [markdown]
# Read files: Restaurant - Week 1 Sales.csv  and  Restaurant - Week 2 Sales.csv. Concat them.

# %%
import pandas as pd
customer=pd.read_csv('Restaurant - Customers.csv')
foods=pd.read_csv('Restaurant - Foods.csv')
week1=pd.read_csv('Restaurant - Week 1 Sales.csv')
week2=pd.read_csv('Restaurant - Week 2 Sales.csv')
satisfaction=pd.read_csv('Restaurant - Week 1 Satisfaction.csv')
display(week1,week2)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          147        8
# 221          745        4
# 222          184        3
# ...

# %%
abc=pd.concat([week1,week2],keys=["A","B"])
abc
# Out:
#        Customer ID  Food ID
# A 0            537        9
#   1             97        4
#   2            658        1
#   3            202        2
#   4            155        9
#   5            213        8
#   6            600        1
#   7            503        5
#   8             71        3
#   9            174        3
#   10           961        9
#   11           966        5
#   12           641        4
#   13           288        2
#   14           149        4
#   15           954        2
#   16           147        9
#   17           155        1
#   18           550        6
#   19           101        7
#   20           549        6
#   21            75        6
#   22            78        7
#   23           514        5
#   24           833        7
#   25           329        8
#   26           586       10
#   27           341        1
#   28           519       10
#   29           680        9
# ...            ...      ...
# B 220          495        2
# ...

# %% [markdown]
# ### Que 2

# %% [markdown]
# For the above concatenated file give the Customer ID of file: Restaurant - Week 2 Sales.csv. with index=240.

# %%
abc.ix[("B",240),"Customer ID"]
# Out:
# C:\Users\vijay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 734

# %% [markdown]
# ### Que 3

# %% [markdown]
# Read files:
# Restaurant - Week 1 Sales.csv.
# Restaurant - Week 2 Sales.csv.
# Show dataframe containing Food ID of both the files with their common Customer ID.

# %%
pd.merge(week1,week2, on="Customer ID",suffixes=["-A","-B"])
# Out:
#     Customer ID  Food ID-A  Food ID-B
# 0           537          9          5
# 1           155          9          3
# 2           155          1          3
# 3           503          5          8
# 4           503          5          9
# 5           550          6          7
# 6           101          7          4
# 7            75          6          4
# 8            77          1          7
# 9            77          9          7
# 10           77          2          7
# 11           77          9          7
# 12          628          4          7
# 13          798          9          5
# 14          798          1          5
# 15          462          3          8
# 16          304          3          3
# 17          304          2          3
# 18          189          4          5
# 19          799          8          7
# 20           30          2          4
# 21          249          9          6
# 22          677         10          3
# 23          741          3          8
# ...

# %% [markdown]
# ### Que 4

# %% [markdown]
# Show dataframe containing Food ID of both the files with a single column of Customer ID (of both files). Therefore specify which Food ID data has been taken from which file. Use files: Restaurant - Week 1 Sales.csv, and Restaurant - Week 2 Sales.csv.

# %%
pd.merge(week1,week2, on="Customer ID", how="outer",suffixes=["-Week1","-Week2"],indicator=True)
# Out:
#      Customer ID  Food ID-Week1  Food ID-Week2      _merge
# 0            537            9.0            5.0        both
# 1             97            4.0            NaN   left_only
# 2            658            1.0            NaN   left_only
# 3            202            2.0            NaN   left_only
# 4            155            9.0            3.0        both
# 5            155            1.0            3.0        both
# 6            213            8.0            NaN   left_only
# 7            600            1.0            NaN   left_only
# 8            503            5.0            8.0        both
# 9            503            5.0            9.0        both
# 10            71            3.0            NaN   left_only
# 11            71            8.0            NaN   left_only
# 12           174            3.0            NaN   left_only
# 13           961            9.0            NaN   left_only
# 14           966            5.0            NaN   left_only
# ...

# %% [markdown]
# ### Que 5

# %% [markdown]
# Restaurant - Week 2 Sales.csv,
# Restaurant - Customers.csv.
# Use both files to show the given dataframe. Column:  ID must contain all the data.

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
customer.head()
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
pd.merge(customer,week2,left_on="ID",right_on='Customer ID',how="outer").head(15)
# Out:
#     ID First Name Last Name  Gender        Company  \
# 0    1     Joseph   Perkins    Male        Dynazzy
# 1    2   Jennifer   Alvarez  Female           DabZ
# 2    3      Roger     Black    Male        Tagfeed
# 3    4     Steven     Evans    Male           Fatz
# 4    5       Judy  Morrison  Female        Demivee
# 5    6     Amanda    Howell  Female  Thoughtbridge
# 6    7     Johnny      Reid    Male    Babblestorm
# 7    8    Frances     Adams  Female       Dabshots
# 8    9    Gregory   Chapman    Male           Eayo
# 9   10     Steven      Ryan    Male        Twinder
# 10  11    Michael  Reynolds    Male         Meevee
# 11  12       Lois   Watkins  Female           Mydo
# 12  13       Ruth   Alvarez  Female    Twitterlist
# 13  14       Adam      Ryan    Male       Photojam
# 14  15      Jesse  Richards    Male        Demimbu
#
#                        Occupation  Customer ID  Food ID
# 0   Community Outreach Specialist          NaN      NaN
# ...

# %% [markdown]
# ### Que 6

# %% [markdown]
# Read files: Restaurant - Week 1 Sales.csv, and Restaurant - Week 1 Satisfaction.csv. Show dataframe containing columns:Customer ID,	Food ID, and Satisfaction Rating

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
satisfaction.head()
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3
# 3                    7
# 4                   10

# %%
pd.merge(week1,satisfaction, how = "left", left_index = True, right_index = True).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %% [markdown]
# ### Que 7

# %% [markdown]
# Read salesman.csv file. Show dataframe which contains maximum revenue made by each salesmen and on which date.

# %%
import pandas as pd
df=pd.read_csv("salesmen.csv")
df.head()
# Out:
#      Date Salesman  Revenue
# 0  1/1/16      Bob     7172
# 1  1/2/16      Bob     6362
# 2  1/3/16      Bob     5982
# 3  1/4/16      Bob     7917
# 4  1/5/16      Bob     7837

# %%
abcd=df.sort_values(["Revenue","Date"],ascending=False)

abcd
# Out:
#           Date Salesman  Revenue
# 89     3/30/16      Bob     9999
# 501    5/15/16   Ronald     9991
# 1647    7/2/16    Oscar     9971
# 708    12/8/16   Ronald     9951
# 165    6/14/16      Bob     9945
# 1322   8/12/16      Jeb     9939
# 771     2/9/16     Dave     9939
# 206    7/25/16      Bob     9934
# 1629   6/14/16    Oscar     9926
# 498    5/12/16   Ronald     9912
# 514    5/28/16   Ronald     9902
# 1547   3/24/16    Oscar     9901
# 112    4/22/16      Bob     9897
# 591    8/13/16   Ronald     9896
# 746    1/15/16     Dave     9883
# 804    3/13/16     Dave     9874
# 258    9/15/16      Bob     9868
# 1246   5/28/16      Jeb     9866
# 7       1/8/16      Bob     9863
# 19     1/20/16      Bob     9863
# 1287    7/8/16      Jeb     9856
# 1620    6/5/16    Oscar     9847
# 87     3/28/16      Bob     9847
# 1225    5/7/16      Jeb     9843
# 1523   2/29/16    Oscar     9843
# 1068   12/2/16     Dave     9842
# 1283    7/4/16      Jeb     9841
# ...
